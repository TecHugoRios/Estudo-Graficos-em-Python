# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
dados = {'Departamento':["Vendas", "Marketing", "TI", "RH", "Financeiro", "Atendimento"],
         'Avaliação Média':[4.2,4.8, 3.9, 4.5, 4.1, 4.7]}

# %%
df = pd.DataFrame(data=dados)
df = df.sort_values(by=['Avaliação Média'], ascending=False)

# %%
media = format(np.mean(list(df['Avaliação Média'])), ".2f")
media = float(media)

# %%
plt.figure(figsize=(10,6))
plt.bar(list(df['Departamento']),list(df['Avaliação Média']))
plt.axhline(y=media,color = 'red', linestyle='--', label=f"Media Geral: {media}", )
plt.legend()
plt.show()
